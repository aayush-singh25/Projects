# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.numbeo.com/cost-of-living/rankings_current.jsp"

# %%
headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
page = requests.get(url, headers=headers)

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
table = soup.find("table", id="t2")

# %%
tbody = table.find("tbody")

# %%
rows = tbody.find_all("tr")[1:]

# %%
data = []

for row in rows:
    cols = row.find_all("td")
    row_data = [col.text.strip() for col in cols]
    data.append(row_data)

# %%
City = []
Cost_of_Living_Index = []
Rent_Index = []
Cost_of_Living_Plus_Rent = []
Groceries_Index = []
Restaurant_Price_Index = []
Local_Purchasing_Power = []
for i in data:
    City.append(i[1])
    Cost_of_Living_Index.append(i[2])
    Rent_Index.append(i[3])
    Cost_of_Living_Plus_Rent.append(i[4])
    Groceries_Index.append(i[5])
    Restaurant_Price_Index.append(i[6])
    Local_Purchasing_Power.append(i[7])

# %%
df = pd.DataFrame({
    "City": City,
    "Cost of Living Index": Cost_of_Living_Index,
    "Rent Index": Rent_Index,
    "Cost of Living + Rent Index": Cost_of_Living_Plus_Rent,
    "Groceries Index": Groceries_Index,
    "Restaurant Price Index": Restaurant_Price_Index,
    "Local Purchasing Power Index": Local_Purchasing_Power
})

# %%
df.to_excel("Numbeo_Cost_of_Living.xlsx", index=False)
print(df.head())
# Out:
#                           City Cost of Living Index Rent Index  \
# 0          Geneva, Switzerland                121.9       65.7
# 1           Basel, Switzerland                117.4       48.5
# 2        Lausanne, Switzerland                115.8       53.8
# 3          Lugano, Switzerland                115.1       45.5
# 4  George Town, Cayman Islands                113.3       75.0
#
#   Cost of Living + Rent Index Groceries Index Restaurant Price Index  \
# 0                        96.1           120.7                  128.2
# 1                        85.7           117.4                  118.4
# 2                        87.3           115.4                  118.3
# 3                        83.1           113.5                  130.3
# 4                        95.7           121.1                  107.4
#
#   Local Purchasing Power Index
# 0                        167.7
# 1                        192.7
# 2                        182.1
# 3                        160.2
# ...
